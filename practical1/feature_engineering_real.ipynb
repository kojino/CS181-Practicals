# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
benzene = pd.read_pickle('pkl/benzene.pkl')
plt.scatter(benzene['rings'], benzene['gap'], alpha=0.2)

# %%
nAtoms = pd.read_pickle('pkl/nAtoms.pkl')
plt.scatter(nAtoms['nAtoms'], nAtoms['gap'], alpha=0.2)

# %%
nBonds = pd.read_pickle('pkl/nBonds.pkl')
plt.scatter(nBonds['nBonds'], nBonds['gap'], alpha=0.2)

# %%
csp3 = pd.read_pickle('pkl/csp3.pkl')
plt.scatter(csp3['csp3'], csp3['gap'], alpha=0.2)

# %%
rings = pd.read_pickle('pkl/rings.pkl')
plt.scatter(rings['rings'], rings['gap'], alpha=0.2)

# %%
weight = pd.read_pickle('pkl/weight.pkl')
plt.scatter(weight['weight'], weight['gap'], alpha=0.2)

# %%
chi0n = pd.read_pickle('pkl/chi0n.pkl')
plt.scatter(chi0n['chi0n'], chi0n['gap'], alpha=0.2)

# %%
kappa3 = pd.read_pickle('pkl/kappa3.pkl')
plt.scatter(kappa3['kappa3'], kappa3['gap'], alpha=0.2)

# %%
df_updated = pd.read_pickle('df_updated.pkl')

# %%
plt.hist(df_updated.kappa3)
# Out:
# (array([   1062.,   23635.,   79900.,  217716.,  311788.,  143785.,
#          113189.,   93417.,   14928.,     580.]),
#  array([ 0.80778982,  1.05097422,  1.29415861,  1.53734301,  1.7805274 ,
#          2.0237118 ,  2.26689619,  2.51008059,  2.75326498,  2.99644938,
#          3.23963377]),
#  <a list of 10 Patch objects>)
